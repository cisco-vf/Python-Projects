# %% [markdown]
# <img src="https://blog.logomyway.com/wp-content/uploads/2020/03/airbnb-logo.jpg">

# %% [markdown]
# ### Proyecto elaborado por: Francisco Vela Flores

# %% [markdown]
# **Airbnb** fué fundada por Brian Chesky, Joe Gebbia y Nathan Blecharczyk en San Francisco, California. Es una compañía que se encuentra activa desde el año 2008 y consiste en una plataforma digital dedicada a la oferta de alojamientos a particulares y turísticos (alquiler vacacional) mediante la cual los anfitriones pueden publicitar y contratar el arriendo de sus propiedades con sus huéspedes; anfitriones y huéspedes pueden valorarse mutuamente, como referencia para futuros usuarios. Airbnb tiene una oferta de unas 2 millones de propiedades en 192 países y 33 mil ciudades alrededor del mundo.

# %% [markdown]
# <img src ="https://www.clickz.com/wp-content/uploads/2016/03/airbnb-bad.png">

# %% [markdown]
# [Link al website de Airbnb](https://www.airbnb.com)

# %% [markdown]
# # Objetivo del Proyecto

# %% [markdown]
# El presente proyecto representa los servicios de alquiler de Airbnb en los 05 distritos del estado de Nueva York, (Brooklyn, Manhattan, Queens, Bronx y Staten Island) en los Estados Unidos y tiene como objetivo, analizar a AIRBNB como una de las mejores alternativas para rentar habitaciones en dichos Distritos, dependiendo del presupuesto que tienes destinado y los motivos de visita en la ciudad, ya sea por un viaje de negocios, turismo o familiar.

# %% [markdown]
# # Contexto Comercial

# %% [markdown]
# Para ponernos en contexto de cuál es el ámbito del estado de Nueva York en los Estados Unidos, revisaremos cómo se encuentran distribuidos sus 05 distritos (Brooklyn, Manhattan, Queens, Bronx y Staten Island) con la finalidad de poder tener una referencia a nivel general y principalmente comercial.

# %% [markdown]
# **Mapa del Estado de Nueva York y sus Distritos**
#
# ![Airbnb_logo](https://nuevayork.travel/wp-content/uploads/2013/02/BARRIOS_NY.jpg)

# %% [markdown]
# ### Manhattan
#
# Manhattan es el distrito más famoso e importante de la ciudad de Nueva York.
# Cuenta con poco más de un millón y medio de habitantes y es donde se concentran la mayoría de los rascacielos y de las atracciones turísticas. Es una isla alargada que limita al oeste con el estado de New Jersey, al norte con el Bronx y al este con Queens y Brooklyn.
#
# Se divide en cinco zonas, que de norte a sur son: _Washington Heights, Harlem, Upper Manhattan, Midtown y Lower Manhattan._
#
# **Atracciones en Manhattan**
#
# - En Manhattan se concentran prácticamente todos los lugares de visita obligatoria en Nueva York, sobretodo en el Midtown.
#
# - En el Lower Manhattan nos encontramos una gran extensión verde, el Battery Park City, desde donde salen los ferries a Ellis
# Island y Liberty Island, que alberga la Estatua de la Libertad y Wall Street.
#
# - En el Midtown se encuentran algunos lugares tan famosos como el Empire State Building, la concurrida Times Square, el
# mirador Top of the Rock o museos tan importantes como el MoMA.
#
# - En el Upper Manhattan y prácticamente en el centro de la isla se ubica Central Park, uno de los parques públicos más famosos
# del mundo.
#
# ![Airbnb_logo](https://nuevayork.travel/wp-content/uploads/2013/03/SKYSCRAPER.jpg)

# %% [markdown]
# ### Brooklyn
#
# Brooklyn es el distrito más poblado de la ciudad, sus barrios están muy de moda y cuenta con una gran variedad de razas y étnias.
#
# ![Airbnb_logo](https://nuevayork.travel/wp-content/uploads/2013/03/Brooklyn.jpg)

# %% [markdown]
# ### Queens
#
# Queens es el más grande de los condados y con casi de dos millones y medio de habitantes. Es el más diverso del país.
# En Queens se ubican dos aeropuertos de la ciudad, el aeropuerto de La Guardia y el JFK.
#
# ![Airbnb_logo](https://nuevayork.travel/wp-content/uploads/2013/03/Queens.jpg)

# %% [markdown]
# ### Bronx
#
# El Bronx es el único distrito de Nueva York que se ubica en el continente. Es también multiétnico, predominando la raza negra y los puertorriqueños. En él nació el rap y el hip hop.
#
# ![Airbnb_logo](https://nuevayork.travel/wp-content/uploads/2013/03/Bronx.jpg)

# %% [markdown]
# ### Staten Island
#
# Staten Island se ubica al sur de la ciudad y conecta con Brooklyn por el puente de Verrazano – Narrows, a Manhattan con el ferry de Staten Island y a New Jersey por tres puentes.
#
# ![Airbnb_logo](https://nuevayork.travel/wp-content/uploads/2013/03/Staten-Island.jpg)

# %% [markdown]
# ### En base a ésta información podemos deducir lo siguiente:
#
#
# Usualmente para rentar y/o reservar una habitación en la ciudad de Nueva York, una persona común puede realizarlo de las siguientes 3 maneras:
#
# #### 1. A través de una búsqueda presencial en la propia ciudad y/o por contactos de residentes.
# #### 2. A través de una reserva vía web del tipo Booking.com, etc.
# #### 3. A través de la APP y/o Plataforma de AIRBNB.

# %% [markdown]
# Para fines de este proyecto analizaremos la 3ra opción, **renta de habitaciones bajo la APP y/o Plataforma de AIRBNB.**

# %% [markdown]
# # Problema Comercial

# %% [markdown]
# Actualmente uno de los mayores problemas que tiene el sector es la confianza de los huéspedes a la hora de reservar: una de las mayores preocupaciones a la hora de alquilar un alojamiento privado a través de internet es el miedo a que se trate de una estafa. En este caso, al utilizar AIRBNB puedes consultar todas las evaluaciones de los anteriores inquilinos y, además, éste actúa como intermediario a la hora de pagar, por lo que si hay algún problema con la reserva, normalmente es la propia plataforma la que responde.
#
# Por otra parte, no sólo el anfitrión es evaluado, sino también el huésped. Ambos tienen que crearse una cuenta para utilizar la web y al finalizar la estancia tienen que escribir una evaluación mutua. Si una de las partes falla en escribir su crítica, ninguna de las dos es publicada. De esta forma el anfitrión también tiene una herramienta de referencia a la hora de aceptar o rechazar una reserva.

# %% [markdown]
# ### ii) Análisis de Hipótesis
#
# Realizaremos el siguiente análisis de hipótesis para absolver algunas dudas referente al tema:
#
# 1. Cuánto más costoso un alquiler, es mayor el pago de servicio.
# 2. Los alquileres en promedio son más costosos en Manhattan que en Brooklyn.
# 3. Los hoteles no son las ofertas más elegidas, sino más bien alojamientos de particulares.
# 4. Las políticas de cancelación son estrictas, ya que los hosts no quieren perder la renta por alquiler de su inmueble.
# 5. Las construcciones son modernas, para que sean más atractivas al público.
# 6. La demanda de cuartos compartidos es mayor en Manhattan y Brooklyn debido a la cercanía al centro del movimiento financiero y turístico de Nueva York.
# 7. Las personas que están más dispuestas a pagar por habitaciones privadas o dentro de casas y/o apartamentos son más críticas al momento de dar un review del servicio ofrecido.

# %% [markdown]
# # Contexto Analítico

# %% [markdown]
# Se busca analizar la oferta de lugares para rentar temporalmente en ellos mediante esta plataforma, a través de distintas variables como antigüedad de la construcción, tipos de habitación (privada, hotel, compartida), precios de alquiler y pago de servicios, mínimo de noches, disponibilidad durante el año, política de cancelación, reglas de la casa, entre otros. Además, se considerará la cantidad de reviews que posean ya que esta variable es muy importante para los posibles clientes. Este dataset contiene datos públicos que pueden extraerse directamente desde la web de Airbnb.

# %% [markdown]
# <img src="https://link.estadao.com.br/blogs/lol/wp-content/uploads/sites/367/2014/07/logo-airbnb.jpg">

# %% [markdown]
# ### iii) Análisis Exploratorio de Datos (EDA)

# %% [markdown]
# ### Extracción de datos

# %%
#Importamos librerías a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MiniMap
import warnings
warnings.filterwarnings("ignore")

# %%
#Abrimos el dataset
airbnb = pd.read_csv("./Airbnb_Open_Data.csv", low_memory = False)

#se quitan espacios entre nombres de columnas y se agrega un _
airbnb.columns = airbnb.columns.str.replace(' ', '_') 
airbnb.shape
# Out:
# (102599, 26)

# %%
#Revisamos los 5 primeros registros
airbnb.head()
# Out:
#         id                                              NAME      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service_fee minimum_nights  \
# ...

# %%
#Analizamos la información de las columnas y tipo de variables
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host_id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host_name                       102193 non-null  object
#  5   neighbourhood_group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country_code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
#Revisamos estadísticos de las variables numéricas
airbnb.describe()
# Out:
#                  id       host_id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction_year  minimum_nights  number_of_reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %% [markdown]
# ### Transformación de datos

# %%
#Analizamos los distritos de New York y observamos que hay 2 distritos (Manhattan y Brooklyn) que tienen doble registro por estar mal redactados
airbnb['neighbourhood_group'].value_counts()
# Out:
# Manhattan        43792
# Brooklyn         41842
# Queens           13267
# Bronx             2712
# Staten Island      955
# brookln              1
# manhatan             1
# Name: neighbourhood_group, dtype: int64

# %%
#Corregimos los distritos mal redactados
airbnb['neighbourhood_group'].replace(['manhatan','brookln'],['Manhattan','Brooklyn'],inplace=True)
airbnb['neighbourhood_group'].value_counts()
# Out:
# Manhattan        43793
# Brooklyn         41843
# Queens           13267
# Bronx             2712
# Staten Island      955
# Name: neighbourhood_group, dtype: int64

# %%
#ServiceFee y Price traen símbolo $, se lo quitaremos para poder cambiar el tipo de dato de object a float
airbnb['price']=airbnb['price'].apply(lambda x: x.replace('$','') if pd.isna(x) == False else x)
airbnb['service_fee']=airbnb['service_fee'].apply(lambda x: x.replace('$','') if pd.isna(x) == False else x)

#Cambiamos el tipo de dato de price y ServiceFee
airbnb['service_fee']=airbnb['service_fee'].astype(float)
airbnb['price']=airbnb['price'].apply(lambda x: x.replace(',','') if pd.isna(x) == False else x)
airbnb['price']=airbnb['price'].astype(float)

# %%
#Last_Review está en tipo dato object, lo pasaremos a DateTime para poder usarlo como fecha
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'])

#Last_Review trae dato con año: 2058 -> esto es un dato erróneo, y genera gran dispersión en los datos.
#Por lo tanto lo reemplazaremos por la media.
airbnb.loc[airbnb[airbnb['last_review'].apply(lambda x: x.year) > 2022].index,'last_review'] = airbnb['last_review'].mean()

#Last_Review reemplazaremos los valores null por la media también
airbnb.loc[airbnb['last_review'].isnull(), 'last_review'] = airbnb['last_review'].mean()

#Revisamos que haya quedado correctamente Last_Review
airbnb['last_review'].min(), airbnb['last_review'].max()
# Out:
# (Timestamp('2012-07-11 00:00:00'), Timestamp('2022-05-21 00:00:00'))

# %%
#Cambiamos los valores nulos de la variable 'Construction_year' por la media
#Asimismo, cambiamos el tipo de variable 'Construction_year' de Float a Integer
airbnb.loc[airbnb['Construction_year'].isnull(), 'Construction_year'] = airbnb['Construction_year'].mean()
airbnb['Construction_year'] = airbnb['Construction_year'].round().astype(int)

# %%
#Mostramos el resultado final para la variable 'Construction_year'
airbnb['Construction_year']
# Out:
# 0         2020
# 1         2007
# 2         2005
# 3         2005
# 4         2009
#           ...
# 102594    2003
# 102595    2016
# 102596    2009
# 102597    2015
# 102598    2010
# Name: Construction_year, Length: 102599, dtype: int32

# %%
#minimun_nights trae dato negativo alto: -1223 -> esto es un dato erróneo, y genera gran dispersión en los datos.
#Lo reemplazaremos por la media.
airbnb.loc[airbnb[airbnb['minimum_nights'].apply(lambda x: x) < 0].index,'minimum_nights'] = airbnb['minimum_nights'].mean()

# %%
#Llenamos los campos con datos nulos en la columna "price" con el número 0
airbnb["price"].fillna(0)
# Out:
# 0          966.0
# 1          142.0
# 2          620.0
# 3          368.0
# 4          204.0
#            ...
# 102594     844.0
# 102595     837.0
# 102596     988.0
# 102597     546.0
# 102598    1032.0
# Name: price, Length: 102599, dtype: float64

# %%
#Revisamos datos de las columnas host identity verified, instant_bookable, roomtype, cancellation_policy, review_rate_number y
#lo cambiaremos a tipo de dato categoría
print(airbnb['host_identity_verified'].value_counts())
print(airbnb['instant_bookable'].value_counts())
print(airbnb['room_type'].value_counts())
print(airbnb['cancellation_policy'].value_counts())
print(airbnb['review_rate_number'].value_counts())

#Hacemos el cambio de tipo de dato a Categoría
airbnb = airbnb.astype({'room_type':'category','cancellation_policy':'category',
                        'instant_bookable':'category','host_identity_verified':'category',
                        'review_rate_number':'category','neighbourhood_group':'category'})
# Out:
# unconfirmed    51200
# verified       51110
# Name: host_identity_verified, dtype: int64
# False    51474
# True     51020
# Name: instant_bookable, dtype: int64
# Entire home/apt    53701
# Private room       46556
# Shared room         2226
# Hotel room           116
# Name: room_type, dtype: int64
# moderate    34343
# strict      34106
# flexible    34074
# Name: cancellation_policy, dtype: int64
# 5.0    23369
# 4.0    23329
# 3.0    23265
# 2.0    23098
# 1.0     9212
# Name: review_rate_number, dtype: int64

# %%
#Validamos los cambios de tipo de variable realizados
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host_id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  category
#  4   host_name                       102193 non-null  object
#  5   neighbourhood_group             102570 non-null  category
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country_code                    102468 non-null  object
# ...

# %%
#Separamos variables categóricas y numéricas para que nos permitan hacer mayor análisis
categoricas = ['host_identity_verified','neighbourhood_group','instant_bookable','cancellation_policy','room_type','Construction_year','review_rate_number']
numericas = ['price','service_fee','minimum_nights','number_of_reviews','reviews_per_month','availability_365']

# %% [markdown]
# ### Análisis de Datos

# %%
#Agrupamos información por distrito para posibles insights
Manhattan = airbnb[airbnb['neighbourhood_group']=="Manhattan"]
Brooklyn = airbnb[airbnb['neighbourhood_group']=="Brooklyn"]
Queens = airbnb[airbnb['neighbourhood_group']=="Queens"]
Bronx = airbnb[airbnb['neighbourhood_group']=="Bronx"]
Staten_Island = airbnb[airbnb['neighbourhood_group']=="Staten Island"]

# %%
Queens[Queens['room_type']=="Private room"]
# Out:
#              id                                               NAME  \
# 47      1027294  1 Stop fr. Manhattan! Private Suite,Landmark B...
# 144     1080867                 Fully Furnished Basement Apartment
# 162     1090809            A room w/ a Manhattan view, longer stay
# 197     1110139                              ( F) Excellent/Pvt Rm
# 201     1112348                 Clean and convenient 2BR apartment
# ...         ...                                                ...
# 102491  6035551                  Large bedroom in Astoria/LIC area
# 102504  6042730                Private Room in large 2 bedroom apt
# 102528  6055986                Furnished room in Astoria apartment
# 102568  6078078                Furnished Bedroom in 2 Bedroom apt.
# 102580  6084705                Near LGA, Citifield, US Open Tennis
#
#             host_id host_identity_verified host_name neighbourhood_group  \
# 47      81253735818            unconfirmed  Victoria              Queens
# ...

# %%
Manhattan[Manhattan['room_type']=="Entire home/apt"]
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 10      1006859                Cute & Cozy Lower East Side 1 bdrm
# 11      1007411                  Beautiful 1br on Upper West Side
# ...         ...                                               ...
# 102586  6088019                    Patio Oasis in Upper East Side
# 102588  6089124          Loft Space for Events, Meetings & Shoots
# 102591  6090781                Columbus Ave Apt 1 block from Park
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102598  6094647                              585 sf Luxury Studio
#
#             host_id host_identity_verified host_name neighbourhood_group  \
# 1       52335172823               verified     Jenna           Manhattan
# ...

# %% [markdown]
# ### Análisis general de datos con visualizaciones

# %%
#Hacemos funcion que grafique las variables categóricas con las numéricas y me de insights
for var_cat in categoricas:
    frecuencia = airbnb[var_cat].value_counts()
    df_frecuencias = pd.DataFrame({var_cat: frecuencia.index.tolist(), 'cantidad':frecuencia.tolist()})
    sns.barplot(x=var_cat, y='cantidad', data=df_frecuencias)
    plt.show()

# %%
#Buscamos correlaciones entre variables con un mapa de calor (heatmap)
f, ax = plt.subplots(figsize=(10,8))
corr = airbnb.corr()
sns.heatmap(corr)
plt.show()

# %% [markdown]
# **Interpretación:** De acuerdo al Mapa de calor, podemos apreciar que únicamente las variables price(precio) y service_fee(pago de servicios) tienen una alta correlación.
# En segundo lugar, las variables reviews_per_month (reviews por mes) y number_of_reviews (número de reviews) tienen menos del 0.6 lo cual no es una buena referencia a tomar.

# %% [markdown]
# ## Damos respuesta a las Hipotesis planteadas

# %% [markdown]
# #### 1. Cuánto más costoso un alquiler, es mayor el pago de servicio.

# %%
#Validamos la alta correlación existente entre el precio y el service_fee
airbnb.plot(kind = "scatter", x= "price" , y="service_fee")
# Out:
# <AxesSubplot:xlabel='price', ylabel='service_fee'>

# %% [markdown]
# **Interpretación:** Este gráfico da respuesta a la hipótesis 1, y la confirma. podemos apreciar la clara correlación existente entre la variable price(precio) y service_fee (pago de servicios), por ende, a mayor costo de alquiler, mayor es el pago del servicio. (Tener en cuenta que correlación no expresa causalidad necesariamente)

# %% [markdown]
# ### Hipótesis 2 y 3

# %% [markdown]
# #### 2. Los alquileres en promedio son más costosos en Manhattan que en Brooklyn.
# #### 3. Los hoteles no son las ofertas más elegidas, sino más bien alojamientos de particulares.

# %%
sns.catplot(x="neighbourhood_group", y="price", data=airbnb, kind="box", col="room_type")
plt.show()

# %% [markdown]
# **Interpretación:**
# - Este gráfico da respuesta a la hipótesis 2, y la rechaza. Ya que en promedio los alquileres en Brooklyn son más costosos que en Manhattan.
# - Este gráfico da respuesta a la hipótesis 3, y la confirma. Ya que las habitaciones de hotel sólo se encuentran en 3 distritos.
#
# Asimismo, podemos apreciar que a excepción de las habitaciones de hotel los otros tipos de habitaciones tienen una mediana de precio que difiere muy poco tanto para aumento o reducción de precio para los 5 distritos, asimismo, podemos verificar que en Brooklyn los costos de las habitaciones de hotel así como tienen un monto mínimo más alto, tienen un monto máximo menor que Manhattan y Queens, por último, en Staten Island el 25% de la renta mínima para habitaciones compartidas es mayor que la de los demás distritos.

# %% [markdown]
# ### Hipótesis 4

# %% [markdown]
# #### 4. Las políticas de cancelación son estrictas, ya que los hosts no quieren perder la renta por alquiler de su inmueble.

# %%
serie_politica= airbnb['cancellation_policy'].value_counts()
serie_politica
# Out:
# moderate    34343
# strict      34106
# flexible    34074
# Name: cancellation_policy, dtype: int64

# %%
fig,ax = plt.subplots(figsize =(10, 6))
politica= ["moderate", "strict", "flexible"]
ax.pie(serie_politica, labels = politica,autopct='%1.1f%%')
ax.set_title('Politicas de cancelación')
# Out:
# Text(0.5, 1.0, 'Politicas de cancelación')

# %% [markdown]
# **Interpretación:** Este gráfico responde a la hipótesis 4, y la rechaza. Ya que las políticas de cancelación son bastante parejas y no hay una marcada rigidez por parte delos host.

# %% [markdown]
# ### Hipótesis 5

# %% [markdown]
# #### 5. Las construcciones son modernas, para que sean más atractivas al público.

# %%
#Desagregamos por Año de construccion, apreciando de primera impresión la no existencia de muchas diferencias por año 
fig, ax = plt.subplots(figsize = (13, 6))
frec_construccion = airbnb['Construction_year'].value_counts()
df_frec_construccion = pd.DataFrame({'construccion': frec_construccion.index.tolist(), 'cantidad':frec_construccion.tolist()})
sns.barplot(x='construccion', y='cantidad', data = df_frec_construccion)
plt.show()

# %%
#Desagregamos por Año de construccion a un nivel más amplio a fin de apreciar de mejor manera las diferencias por año
frec_construccion = airbnb['Construction_year'].value_counts()
plt.figure(figsize=(15,6))
sns.pointplot(x=frec_construccion.index, y=frec_construccion.values, color='blue')
plt.xlabel("Año de Construcción")
plt.ylabel("Cantidad")
plt.title("Año de Construcción", size=20);

# %% [markdown]
# **Interpretación:** Este gráfico responde a la hipótesis 5, y la confirma. Podemos ver que todos los host son relativamente nuevos, ninguno excede los 20 años de antiguedad. Todos son desde 2003 en adelante y de proporciones bastante parejas.Asimismo, podemos apreciar que desde el 2003 al 2022 el número de construcciones por año no bajan de las 5,000, teniendo como años pico el 2006, 2008, 2012, 2014 y 2019.

# %% [markdown]
# ### Hipótesis 6

# %% [markdown]
# #### 6. La demanda de cuartos compartidos es mayor en Manhattan y Brooklyn debido a la cercanía al centro del movimiento financiero y turístico de Nueva York.

# %%
fig, ax = plt.subplots(figsize = (13, 6))
sns.stripplot(x="neighbourhood_group", y="price", hue="room_type", data=airbnb, jitter=0.4, dodge=True)
plt.show()

# %% [markdown]
# **Interpretación:** El presente gráfico da respuesta la Hipótesis 6 y la confirma, asimismo, nos permite apreciar como se distribuyen las rentas de los diferentes tipos de habitaciones Airbnb en los 5 distritos de Nueva York, por lo tanto, vemos que:
# 1. **Bronx:** predominan rentas en habitaciones privadas, casa o departamentos, en mucho menor cantidad las habitaciones compartidas.
# 2. **Brooklyn:** predominan rentas en habitaciones privadas, casa o departamentos y habitaciones compartidas, son contadas las habitaciones de hotel
# 3. **Manhattan:** predominan rentas en habitaciones privadas, casa o departamentos y habitaciones compartidas, a comparación de los otros distritos son mayores las habitaciones de hotel que se rentan
# 4. **Queens:** predominan rentas en habitaciones privadas, casa o departamentos, habitaciones compartidas en menor cantidad, son contadas las habitaciones de hotel
# 5. **Staten Island:** predominan rentas en habitaciones privadas, casa o departamentos en menor cantidad que los otros distritos, son contadas las habitaciones compartidad y no se rentan habitaciones de hotel

# %% [markdown]
# ### Hipótesis 7

# %% [markdown]
# #### 7. Las personas que están más dispuestas a pagar por habitaciones privadas o dentro de casas y/o apartamentos son más críticas al momento de dar un review del servicio ofrecido.

# %%
sns.catplot(x="review_rate_number", data=airbnb, kind="count", col="room_type")
plt.show()

# %% [markdown]
# **Interpretación:** El presente gráfico da respuesta a la Hipótesis 7 y la confirma ya que podemos apreciar que existen mayores reviews tanto positivos como negativos en los alquileres de habitaciones privadas y habitaciones dentro de una casa y/o apartamento.

# %% [markdown]
# ### iv) Recomendaciones

# %% [markdown]
# Como recomendaciones podemos indicar qué, de los 05 distritos de Nueva York (Manhattan, Staten Island, Brooklyn, Bronx y Queens) existe mayor preferencia por la renta de habitaciones bajo AIRBNB en los distritos de Manhattan, Brooklyn y Queens, entendiéndose que son los distritos mas céntricos y de mejor acceso para realizar actividades de negocios o turismo en Nueva York y dentro del tipo de habitaciones que suelen rentar en mayor volúmen podemos ver una indiscutible preferencia por las habitaciones privadas y las que se rentan dentro de casas o departamentos.

# %% [markdown]
# ### Posteriormente procedo a realizar Modelos Estadísticos que nos permitan hacer mayor análisis a las variables con alto nivel de correlación y obtener respuestas que complementen las hipótesis respondidas

# %% [markdown]
# ## Modelo de Regresión Lineal

# %%
#Importamos las librerías necesarias para los Modelos
import sklearn as sk

from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Definimos las Features numéricas
df_num = airbnb.select_dtypes('number')
df_num['y'] = airbnb['price']
df_num = df_num.drop('price', axis=1)
df_num.head()
# Out:
#         id      host_id       lat      long  Construction_year  service_fee  \
# 0  1001254  80014485718  40.64749 -73.97237               2020        193.0
# 1  1002102  52335172823  40.75362 -73.98377               2007         28.0
# 2  1002403  78829239556  40.80902 -73.94190               2005        124.0
# 3  1002755  85098326012  40.68514 -73.95976               2005         74.0
# 4  1003689  92037596077  40.79851 -73.94399               2009         41.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0            10.0                9.0               0.21
# 1            30.0               45.0               0.38
# 2             3.0                0.0                NaN
# 3            30.0              270.0               4.64
# 4            10.0                9.0               0.10
#
#    calculated_host_listings_count  availability_365      y
# 0                             6.0             286.0  966.0
# ...

# %%
len(df_num)
# Out:
# 102599

# %% [markdown]
# ***Valores duplicados***

# %%
#Eliminamos valores duplicados
df_num.drop_duplicates(inplace=True) #df_num = df_num.drop_duplicates()

# %%
len(df_num)
# Out:
# 102058

# %%
#Nos quedamos únicamente con las columnas:
columnas = df_num.columns.tolist()
columnas
# Out:
# ['id',
#  'host_id',
#  'lat',
#  'long',
#  'Construction_year',
#  'service_fee',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'y']

# %%
df_num['y']
# Out:
# 0          966.0
# 1          142.0
# 2          620.0
# 3          368.0
# 4          204.0
#            ...
# 102053     696.0
# 102054     909.0
# 102055     387.0
# 102056     848.0
# 102057    1128.0
# Name: y, Length: 102058, dtype: float64

# %% [markdown]
# **ii) Elegimos un Algoritmo de Regresión para entrenar con los datos elegidos**

# %%
# separamos las caracteristicas/features del target
x = df_num[columnas].drop('y', axis=1)
x = x.filter(items=['Construction_year',
 'service_fee',
 'minimum_nights',
 'number_of_reviews',
 'reviews_per_month',
 'calculated_host_listings_count',
 'availability_365'])

# %%
#Reemplazaremos las columnas de x por la media
for var_med in x:
    x[var_med].value_counts()
    x.loc[x[var_med].isnull(), var_med] = x[var_med].mean()
    x[var_med]=x[var_med].round().astype(int)

# %%
df_num['y'].value_counts()
df_num.loc[df_num['y'].isnull(), 'y'] = df_num['y'].mean()
y = df_num['y'].round().astype(int)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102058 entries, 0 to 102057
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Construction_year               102058 non-null  int32
#  1   service_fee                     102058 non-null  int32
#  2   minimum_nights                  102058 non-null  int32
#  3   number_of_reviews               102058 non-null  int32
#  4   reviews_per_month               102058 non-null  int32
#  5   calculated_host_listings_count  102058 non-null  int32
#  6   availability_365                102058 non-null  int32
# dtypes: int32(7)
# memory usage: 3.5 MB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 102058 entries, 0 to 102057
# Series name: y
# Non-Null Count   Dtype
# --------------   -----
# 102058 non-null  int32
# dtypes: int32(1)
# memory usage: 1.2 MB

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                    test_size=0.2, 
                                                    random_state=42)

print('Tamaño del set de entrenamiento:', x_train.shape)
print('Tamaño del set de testeo:', x_test.shape)
# Out:
# Tamaño del set de entrenamiento: (81646, 7)
# Tamaño del set de testeo: (20412, 7)

# %%
print("x_train")
x_train
# Out:
# x_train
#        Construction_year  service_fee  minimum_nights  number_of_reviews  \
# 11987               2015           41               1                  1
# 11418               2012          119               2                 12
# 72598               2022          213               1                  4
# 31228               2006          126               1                  3
# 22915               2021          125               3                  3
# ...                  ...          ...             ...                ...
# 6265                2010          154               3                114
# 54886               2021          213               1                 14
# 76820               2013           35               2                  0
# 860                 2007           63               1                  0
# 15795               2017          138               2                  0
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
print("y_train")
y_train
# Out:
# y_train
# 11987     203
# 11418     593
# 72598    1065
# 31228     631
# 22915     627
#          ...
# 6265      768
# 54886    1065
# 76820     174
# 860       316
# 15795     692
# Name: y, Length: 81646, dtype: int32

# %%
#Hacemos Regresión
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)
y_pred = regr.predict(x_test)
y_pred
# Out:
# array([764.86436115, 360.54757797, 824.90534713, ..., 500.25139535,
#        330.16181422, 345.51126463])

# %%
y_test
# Out:
# 70586     767
# 21372     359
# 12889     827
# 41824     863
# 34420    1109
#          ...
# 64208     805
# 37468     444
# 51504     502
# 75393     330
# 21176     346
# Name: y, Length: 20412, dtype: int32

# %%
#Imprimimos resultados de Test y Train a analizar
print('Training score: ', regr.score(x_train, y_train))
print('Test score: ', regr.score(x_test,y_test))
# Out:
# Training score:  0.9960156642273799
# Test score:  0.994215716736502

# %%
#Realizamos tabla de predicción del precio sobre el precio original
predictions = pd.DataFrame({"original_Price": y_test.values, "predicted_Price": y_pred})
predictions.head(10)
# Out:
#    original_Price  predicted_Price
# 0             767       764.864361
# 1             359       360.547578
# 2             827       824.905347
# 3             863       864.712817
# 4            1109      1109.101141
# 5            1087      1084.368130
# 6            1014      1014.579040
# 7             263       265.691756
# 8             502       500.226112
# 9             112       111.056614

# %%
#Graficamos la predicción en mención
fig, ax = plt.subplots(figsize=(10,8))
ax = sns.histplot(predictions, element="poly")
plt.show()

# %% [markdown]
# **iii) Calculo de Métricas para validar el Modelo**

# %% [markdown]
# Evaluación del modelo:
#
# El último paso es evaluar el rendimiento del algoritmo. Este paso es particularmente importante para comparar qué tan bien funcionan los diferentes algoritmos en un conjunto de datos en particular. Para los algoritmos de regresión, se utilizan comúnmente tres métricas de evaluación:
#
# El error absoluto medio (MAE)
# El error cuadrático medio (MSE)
# Root Mean Squared Error (RMSE)
#
# Asimismo, añadimos el R2 que nos indica una cifra cercana a 1.

# %%
score = sk.metrics.r2_score(y_test, y_pred)
mae = sk.metrics.mean_absolute_error(y_test, y_pred)
mse = sk.metrics.mean_squared_error(y_test, y_pred)

print('Mean Absolute Error is: {}'.format(mae))
print('Mean Squared Error is: {}'.format(mse))
print('Root Mean_squared_error is:', np.sqrt(mse))

print('sklearn: R2 score for Linear Regression is: {}'.format(score))
# Out:
# Mean Absolute Error is: 2.9551656011297602
# Mean Squared Error is: 636.9528119543052
# Root Mean_squared_error is: 25.237924081712926
# sklearn: R2 score for Linear Regression is: 0.994215716736502

# %%
#Adicionales
error=y_pred-y_test
error
# Out:
# 70586   -2.135639
# 21372    1.547578
# 12889   -2.094653
# 41824    1.712817
# 34420    0.101141
#            ...
# 64208   -0.287769
# 37468    1.574953
# 51504   -1.748605
# 75393    0.161814
# 21176   -0.488735
# Name: y, Length: 20412, dtype: float64

# %%
regr.intercept_
# Out:
# 20.31410137869534

# %% [markdown]
# **iii) Conclusiones con base en los resultados**

# %% [markdown]
# Podemos concluir que al contar con un R2 score de 0.9942146476027874 nuestro modelo predictivo nos indica que existe una buena correlación del precio con las variables independientes (service_fee, minimum_nights, number_of_reviews, reviews_per_month, availability_365) por ende, lo podemos apreciar en el cuadro mostrado donde la predicción de precios de y (y_test) nos arroja precios muy cercanos a los que el modelo tenia en el set de entrenamiento, por lo tanto, podemos tomar en cuenta dichos precios proyectados.

# %% [markdown]
# ### Realizamos otra prueba con el Modelo de Regresión Random Forest

# %%
#Importamos libreria necesaria
from sklearn.ensemble import RandomForestRegressor

Model=RandomForestRegressor(n_estimators=200)
Model.fit(x_train,y_train)
y_pred=Model.predict(x_test)
y_pred
# Out:
# array([764.56 , 359.045, 824.745, ..., 500.515, 330.18 , 346.21 ])

# %%
#Realizamos predicción
predictions = pd.DataFrame({"original_Price": y_test.values, "predicted_Price": y_pred})
predictions.head(10)
# Out:
#    original_Price  predicted_Price
# 0             767          764.560
# 1             359          359.045
# 2             827          824.745
# 3             863          863.730
# 4            1109         1109.720
# 5            1087         1086.195
# 6            1014         1014.490
# 7             263          264.935
# 8             502          501.540
# 9             112          110.005

# %%
#Graficamos las variables Precio Original y Predictivo
sns.scatterplot(x="original_Price",y="predicted_Price", data=predictions)
# Out:
# <AxesSubplot:xlabel='original_Price', ylabel='predicted_Price'>

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------
#
# ### COMPLEMENTAMOS EL PROYECTO CONSUMIENDO UN API REFERENTE AL CLIMA, QUE PODRÍA DARNOS ALGUNA INFORMACIÓN ADICIONAL DE EL CLIMA EN LA CIUDAD DE NUEVA YORK

# %% [markdown]
# ### Consumiendo API

# %%
#Importamos librerías requests y json
import requests
import json

# %%
#Llamamos al API
api_key = "ec1d8e6845f79efab435f727f6077b19"
url = "http://api.openweathermap.org/data/2.5/weather?"
total_url = url + "appid=" + api_key + "&q=" + "New York"
df = requests.get(total_url)
print(df)
# Out:
# <Response [200]>

# %%
#Imprimimos la longitud y resultado de la información
print(len(df.text))
df.text
# Out:
# 507
# '{"coord":{"lon":-74.006,"lat":40.7143},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"base":"stations","main":{"temp":293.53,"feels_like":293.09,"temp_min":289.23,"temp_max":295.34,"pressure":1010,"humidity":56},"visibility":10000,"wind":{"speed":5.81,"deg":360,"gust":8.94},"rain":{"1h":0.17},"clouds":{"all":100},"dt":1683508561,"sys":{"type":2,"id":2008101,"country":"US","sunrise":1683452858,"sunset":1683503851},"timezone":-14400,"id":5128581,"name":"New York","cod":200}'

# %%
#Trasladamos la información a un json
texto=df.text
json.loads(texto)
# Out:
# {'coord': {'lon': -74.006, 'lat': 40.7143},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 293.53,
#   'feels_like': 293.09,
#   'temp_min': 289.23,
#   'temp_max': 295.34,
#   'pressure': 1010,
#   'humidity': 56},
#  'visibility': 10000,
#  'wind': {'speed': 5.81, 'deg': 360, 'gust': 8.94},
#  'rain': {'1h': 0.17},
#  'clouds': {'all': 100},
#  'dt': 1683508561,
#  'sys': {'type': 2,
#   'id': 2008101,
#   'country': 'US',
#   'sunrise': 1683452858,
#   'sunset': 1683503851},
#  'timezone': -14400,
#  'id': 5128581,
#  'name': 'New York',
#  'cod': 200}

# %%
#Vamos separando la información que necesitamos del API
x = df.json()
y = x["main"]
current_temperature = y["temp"]
temp_max = y["temp_max"]
temp_min = y["temp_min"]
current_pressure = y["pressure"]
current_humidity = y["humidity"]
z = x["weather"]
weather_description = z[0]["description"]

# %%
# Imprimimos los valores correspondiente a temperaturas en distintas unidades de medición para la ciudad de Nueva York en USA 
print(" Temperatura (en unidades kelvin) = " + str(round(current_temperature,2)) +
"\n Temperatura (en grados celsius) = " + str((current_temperature) - 273.15) +
"\n Temperatura máxima (en grados celsius) = " + str((temp_max) - 273.15) +
"\n Temperatura mínima (en grados celsius) = " + str((temp_min) - 273.15) +
"\n Presión atmosférica (en unidades hPa) = " + str(current_pressure) +
"\n Humidad (en porcentaje) = " + str(current_humidity) +
"\n Descripción = " + str(weather_description))
# Out:
#  Temperatura (en unidades kelvin) = 293.53
#  Temperatura (en grados celsius) = 20.379999999999995
#  Temperatura máxima (en grados celsius) = 22.189999999999998
#  Temperatura mínima (en grados celsius) = 16.08000000000004
#  Presión atmosférica (en unidades hPa) = 1010
#  Humidad (en porcentaje) = 56
#  Descripción = light rain

# %% [markdown]
# **Nota:** Como nota final, podemos indicar que por el momento se ha procedido a realizar una narrativa adecuada de cómo nuestro proyecto **Airbnb** ha identificado los objetivos del proyecto y en base a la información obtenida se ha realizado un análisis que nos permita obtener insights del contexto comercial y poder dar respuestas a las diferentes hipótesis planteadas, que en un mediano plazo serán insumo para realizar mejoras necesarias para el servicio de alquiler en los 5 distritos e identificar los tipos de habitación y lugares más demandados.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------
#
# ### COMPLEMENTAMOS ACTUALIZANDO EL ANÁLISIS SEGÚN LA CONSIGNA CON EL FEATURE ENGINEERING A FIN DE MEJORAR EL PROCESO DE ENTRENAMIENTO DE ALGORITMOS DE MACHINE LEARNING PARA EL PROYECTO AIRBNB
#
# A continuación voy a proceder a hacer un label enconding a las variables categoricas señaladas anteriormente con la finalidad de poder incluirlas en el análisis y modelado estadístico

# %%
#Visualizamos las variables categoricas = ['host_identity_verified','neighbourhood_group','instant_bookable','cancellation_policy','room_type','Construction_year','review_rate_number']
categoricas
# Out:
# ['host_identity_verified',
#  'neighbourhood_group',
#  'instant_bookable',
#  'cancellation_policy',
#  'room_type',
#  'Construction_year',
#  'review_rate_number']

# %%
pd.options.display.max_columns
pd.options.display.max_columns = None

airbnb.head(10)
# Out:
#         id                                              NAME      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 6  1004650                                   BlissArtsSpace!  61300605564
# 7  1005202                                   BlissArtsSpace!  90821839709
# 8  1005754                   Large Furnished Room Near B'way  79384379533
# 9  1006307                Cozy Clean Guest Room - Family Apt  75527839483
#
#   host_identity_verified host_name neighbourhood_group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# ...

# %%
#Hacemos un label encoding para transformar las variables categóricas en numéricas
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

airbnb["host_identity_verified"] = le.fit_transform(airbnb["host_identity_verified"])
airbnb["neighbourhood_group"] = le.fit_transform(airbnb["neighbourhood_group"])
airbnb["instant_bookable"] = le.fit_transform(airbnb["instant_bookable"])
airbnb["cancellation_policy"] = le.fit_transform(airbnb["cancellation_policy"])
airbnb["room_type"] = le.fit_transform(airbnb["room_type"])
airbnb["Construction_year"] = le.fit_transform(airbnb["Construction_year"])
airbnb["review_rate_number"] = le.fit_transform(airbnb["review_rate_number"])

airbnb.head()
# Out:
#         id                                              NAME      host_id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#    host_identity_verified host_name  neighbourhood_group neighbourhood  \
# 0                       0  Madaline                    1    Kensington
# 1                       1     Jenna                    2       Midtown
# 2                       2     Elise                    2        Harlem
# 3                       0     Garry                    1  Clinton Hill
# 4                       1    Lyndon                    2   East Harlem
#
#         lat      long        country country_code  instant_bookable  \
# ...

# %%
#Visualizamos la conversión de las variables
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host_id                         102599 non-null  int64
#  3   host_identity_verified          102599 non-null  int32
#  4   host_name                       102193 non-null  object
#  5   neighbourhood_group             102599 non-null  int32
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country_code                    102468 non-null  object
#  11  instant_bookable                102599 non-null  int32
# ...

# %%
#Visualizamos el shape
airbnb.shape
# Out:
# (102599, 26)

# %%
#Eliminamos los NaN
airbnb.dropna()
# Out:
#             id                                NAME      host_id  \
# 11114  7139598  Cozy 1 BR on Bedford Avenue, Wburg  73023181304
#
#        host_identity_verified  host_name  neighbourhood_group neighbourhood  \
# 11114                       1  Christina                    1  Williamsburg
#
#             lat      long        country country_code  instant_bookable  \
# 11114  40.71764 -73.95689  United States           US                 1
#
#        cancellation_policy  room_type  Construction_year  price  service_fee  \
# 11114                    2          2                  7  702.0        140.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 11114             1.0                1.0  2016-01-03               0.02
#
#        review_rate_number  calculated_host_listings_count  availability_365  \
# 11114                   0                             1.0             191.0
#
#                                              house_rules   license
# ...

# %%
#Creo nuevo df con las variables a utilizar
df = airbnb.drop(columns=["id", "NAME", "lat", "long", "house_rules", "license", "host_name", "neighbourhood", "country", "country_code", "last_review"])

# %%
#Reemplazamos los NaN por 0
df.fillna(0, inplace=True)

# %%
df.head()
# Out:
#        host_id  host_identity_verified  neighbourhood_group  instant_bookable  \
# 0  80014485718                       0                    1                 0
# 1  52335172823                       1                    2                 0
# 2  78829239556                       2                    2                 1
# 3  85098326012                       0                    1                 1
# 4  92037596077                       1                    2                 0
#
#    cancellation_policy  room_type  Construction_year  price  service_fee  \
# 0                    2          2                 17  966.0        193.0
# 1                    1          0                  4  142.0         28.0
# 2                    0          2                  2  620.0        124.0
# 3                    1          0                  2  368.0         74.0
# 4                    1          0                  6  204.0         41.0
#
# ...

# %% [markdown]
# ### Se va a proceder a mejorar la data realizando un PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
#Preparo las variables y las separo
X = df.drop(columns="price")
y = df["price"]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
#NORMALIZACION
#Aplicamos una transformación de los datos para poder aplicar las propiedades de la distribución normal
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)

# %%
# Calculo la matriz de covarianza
print('NumPy covariance matrix: \n%s' %np.cov(X_std.T))
# Out:
# NumPy covariance matrix:
# [[ 1.00000975e+00  1.55016002e-03  1.78687818e-03  3.73227515e-03
#   -4.11784398e-03 -3.80701950e-03  4.87011426e-03  3.28184269e-03
#   -1.82996358e-03 -4.49895663e-03 -2.82861892e-03  3.15678237e-03
#    1.64664335e-03 -2.11716248e-03]
#  [ 1.55016002e-03  1.00000975e+00  1.42824256e-03 -1.03627743e-03
#   -1.76256030e-03  2.85478951e-03  1.69538333e-03 -3.80327884e-03
#    9.48650401e-04  8.97358211e-04  7.64953365e-04  5.60722777e-03
#   -4.05485133e-03 -6.60159265e-03]
#  [ 1.78687818e-03  1.42824256e-03  1.00000975e+00 -1.93306154e-03
#   -1.49788964e-04 -6.49866541e-03 -5.48157141e-03  5.11875655e-04
#    9.69278592e-03  9.88517767e-03  4.50668702e-02  1.45856549e-02
#    8.80894525e-02  6.09951244e-02]
#  [ 3.73227515e-03 -1.03627743e-03 -1.93306154e-03  1.00000975e+00
#    3.83167793e-04 -2.50865695e-04  2.50890774e-03  4.95862277e-04
#   -3.24959018e-03  4.61918891e-03  1.20112335e-03  4.35111213e-03
#   -6.42758886e-04 -3.46978155e-03]
# ...

# %%
#Calculo los autovalores y autovectores de la matriz
cov_mat = np.cov(X_std.T)
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[ 7.73161074e-03  1.24709829e-03  2.34520392e-03  2.23310025e-03
#    1.61797056e-02 -9.34947657e-02 -1.58365061e-01 -4.81094048e-01
#    4.11437834e-01  6.60579891e-02  2.15233392e-01  5.98461720e-01
#    3.87803144e-01  7.66568968e-02]
#  [-1.12200062e-03 -8.21283922e-04 -2.04988141e-02 -6.58827224e-03
#   -6.38707960e-02  3.56820467e-03 -2.36769032e-01 -1.96298029e-01
#   -2.21814281e-01 -5.68171674e-01 -2.27428682e-01  7.44034465e-02
#    1.39916834e-01 -6.72304049e-01]
#  [-5.29961118e-02  3.47875007e-02  3.43458956e-01 -1.47370470e-01
#    4.85867305e-01  5.68642797e-01 -4.09886021e-01  2.76188661e-01
#    1.40534385e-01  3.94158268e-02 -1.34808627e-01  9.60837790e-02
#    6.22938353e-02  1.11172135e-03]
#  [-6.02976414e-03 -4.53285989e-03 -1.33320934e-02 -8.28042543e-03
#    1.56452889e-02 -4.41722891e-03 -1.27291653e-01 -3.65600529e-01
#    1.38722807e-01  4.12219441e-01 -3.14709240e-01  1.24425319e-01
#   -6.89004391e-01 -2.66732236e-01]
# ...

# %%
#  Hacemos una lista de parejas (autovector, autovalor) 
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Ordenamos estas parejas den orden descendiente con la función sort
eig_pairs.sort(key=lambda x: x[0], reverse=True)

# Visualizamos la lista de autovalores en orden desdenciente
print('Autovalores en orden descendiente:')
for i in eig_pairs:
    print(i[0])
# Out:
# Autovalores en orden descendiente:
# 1.663992925670731
# 1.275669604770611
# 1.0237448044482687
# 1.011417982125152
# 1.0072207887095497
# 1.0037668677766676
# 0.9977151779270556
# 0.9946382843098358
# 0.9910027878656792
# 0.9889002672511997
# 0.957392737358473
# 0.9148610204252856
# 0.7947684371417629
# 0.3750447691213865

# %% [markdown]
# #### Se entiende que una vez ordenados los autovalores, que son una medida de la varianza de los datos, la cuestión es decidir, cuál es el menor número de autovectores o componentes principales, con el que podemos expresar “la esencia principal” de la información contenida en ese dataset. Para ello, usaremos un métrica que se conoce como “varianza explicada”, que muestra cuánta varianza se puede atribuir a cada una de estas componentes principales.

# %%
# A partir de los autovalores, calculamos la varianza explicada
tot = sum(eig_vals)
var_exp = [(i / tot)*100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)

# %%
print (cum_var_exp)
# Out:
# [ 11.88554791  20.99738485  28.30977646  35.53412021  42.72848429
#   49.89817775  57.02464528  64.1291352   71.20765755  78.27116204
#   85.10961494  91.64427283  97.3211349  100.        ]

# %% [markdown]
# ### Continuamos con el desarrollo del Modelo

# %%
#Instancio el modelo y lo entreno
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Muestro los valores del modelo
print("Intercepción:", regressor.intercept_)
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
# Intercepción: 7.009764631535177
#                                  Coefficient
# host_id                        -1.140417e-12
# host_identity_verified         -7.027842e-01
# neighbourhood_group            -3.307409e-01
# instant_bookable               -7.707247e-02
# cancellation_policy            -1.065963e-01
# room_type                       1.749930e-01
# Construction_year              -1.664658e-02
# service_fee                     4.950057e+00
# minimum_nights                  4.632712e-03
# number_of_reviews              -3.196630e-03
# reviews_per_month               1.833012e-01
# review_rate_number              4.380031e-02
# calculated_host_listings_count -6.462224e-03
# availability_365                1.640922e-03

# %%
#Hago la predicción
y_pred = regressor.predict(X_test)

df_pred = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_pred
# Out:
#        Actual    Predicted
# 98862  1197.0  1189.376313
# 72510  1100.0  1096.266742
# 71729   260.0   263.422092
# 65918   956.0   951.090821
# 2060   1144.0  1139.745050
# ...       ...          ...
# 72196   346.0   347.608606
# 51924   503.0   507.389469
# 31665   478.0   482.262902
# 9194    696.0   694.277025
# 61413   883.0   882.411438
#
# [25650 rows x 2 columns]

# %%
#Pruebo la predicción sóbre todo el df, gráfico ilustrativo con una de las variables
df["pred"] = regressor.predict(X)

charges_by_age = df[["neighbourhood_group", "price", "pred"]].groupby("neighbourhood_group").agg({"price":"mean", "pred":"mean"})
charges_by_age.plot()
# Out:
# <AxesSubplot:xlabel='neighbourhood_group'>

# %%
from sklearn import metrics 
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Median Absolute Error:', metrics.median_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r^2 Score:', metrics.r2_score(y_test,y_pred))
# Out:
# Mean Absolute Error: 5.781009619751096
# Median Absolute Error: 2.849686861654618
# Mean Squared Error: 2251.633612486016
# Root Mean Squared Error: 47.45138156561952
# r^2 Score: 0.9794900158606676

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------
#
# ### PARA FINALIZAR, COMPLEMENTO EL PROYECTO CON UN MAPA DE NUEVA YORK DONDE HE FILTRADO A LOS 50 PRIMEROS AIRBNB DE LOS 5 DISTRITOS DE NUEVA YORK QUE TIENEN UN REVIEW DE 5.0 (EL MAXIMO PUNTAJE) LO CUAL PERMITIRÁ TENER ESA REFERENCIA DE PRIMERA MANO AL USUARIO.

# %%
# Extraer las 50 primeras filas con review de 5.0
review5 = airbnb["review_rate_number"] == 5.0
if review5.any():
    subset = airbnb[review5].iloc[:50, :]

# %%
#Generar Mapa de New York
ny_mapa = folium.Map(location=[40.712776, -74.005974], zoom_start=11)

# %%
#Eliminamos los NaN
subset.dropna()
# Out:
# Empty DataFrame
# Columns: [id, NAME, host_id, host_identity_verified, host_name, neighbourhood_group, neighbourhood, lat, long, country, country_code, instant_bookable, cancellation_policy, room_type, Construction_year, price, service_fee, minimum_nights, number_of_reviews, last_review, reviews_per_month, review_rate_number, calculated_host_listings_count, availability_365, house_rules, license]
# Index: []

# %%
#Reemplazamos los NaN por 0 ya que nos emite error de contar con NaN aún
subset.fillna(0, inplace=True)

# %%
#Mostramos en un Mapa los 50 primeros AIRBNB con Review 5.0 ubicados en los 5 distritos de Nueva York, en los cuales si se da click en el marcador de ubicación se podrá tener un popup con una referencia del lugar. Complementario a ello se le puso un Minimap de ubicación en la parte inferior derecha.
for index, row in subset.iterrows():
    folium.Marker(location=[row['lat'], row['long']], popup=row['NAME']).add_to(ny_mapa)

minimap = MiniMap()
ny_mapa.add_child(minimap)
ny_mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### ------------------------------------------------------------ FIN DEL PROYECTO AIRBNB -------------------------------------------------------
